# %% [markdown]
# Load JSON data

# %%
with open("trello_20191106.json", encoding='utf-8') as json_file:
    json_data = json.load(json_file)

# %%
trello_dict = {}
trello_dict = json_data
for key,value in trello_dict.items():
    print(key)
# Out:
# id
# name
# desc
# descData
# closed
# idOrganization
# idEnterprise
# limits
# pinned
# starred
# url
# prefs
# shortLink
# subscribed
# labelNames
# powerUps
# dateLastActivity
# dateLastView
# shortUrl
# idTags
# datePluginDisable
# creationMethod
# ixUpdate
# templateGallery
# enterpriseOwned
# actions
# cards
# labels
# lists
# members
# checklists
# customFields
# memberships
# pluginData

# %%
trello_cards = dict(trello_dict['cards'])
trello_actions = trello_dict['actions']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-d5ce72f0c143> in <module>
# ----> 1 trello_cards = dict(trello_dict['cards'])
#       2 trello_actions = trello_dict['actions']
#
# ValueError: dictionary update sequence element #0 has length 37; 2 is required

# %%
print(trello_actions)
# Out:
# blicAvailable': False, 'username': 'mara26339933'}}, {'id': '5db1434cb817966bec7e1fe7', 'idMemberCreator': '5d83181837b3833746dce248', 'data': {'board': {'id': '5d831cd7b049d33277f96d8c', 'name': 'Workflow DEV', 'shortLink': 'PW2TYzkh'}, 'card': {'id': '5d944c9ea24044614b9980be', 'name': 'BIDWHDEV-3812', 'idShort': 46, 'shortLink': 'gfOEcNHe'}, 'checklist': {'id': '5d944c9ea24044614b9980fd', 'name': 'UAT fejlesztői teszt'}, 'checkItem': {'id': '5d944c9ea24044614b9980ff', 'name': 'Warning-ok ellenőrzése', 'state': 'complete'}}, 'type': 'updateCheckItemStateOnCard', 'date': '2019-10-24T06:23:08.660Z', 'limits': {}, 'memberCreator': {'id': '5d83181837b3833746dce248', 'activityBlocked': False, 'avatarHash': '325b048825140d825705e405af520daa', 'avatarUrl': 'https://trello-avatars.s3.amazonaws.com/325b048825140d825705e405af520daa', 'fullName': 'Mara', 'idMemberReferrer': None, 'initials': 'M', 'nonPublic': {}, 'nonPublicAvailable': False, 'username': 'mara26339933'}}, {'id': '5db1434c8a2cf
# ...
